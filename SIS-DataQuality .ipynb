# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest

# %%
df = pd.read_csv ("SIS_Faculty-List.csv")

# %%
df.head(284)
# Out:
#             ID              Name   Location  Grade               Title  \
# 0    LT9210743        Jim Hunter     London     FA  Faculty - Business
# 1    LT9001784        Jose Nadal     London     FA  Faculty - Business
# 2    LT9062955     Pierre Cornet     London     FA  Faculty - Business
# 3            0       Sally Smith     London     FA  Faculty - Business
# 4            0      Ned Shearer      London  Chair  Faculty - Business
# ..         ...               ...        ...    ...                 ...
# 279          0    Cami Wiegand    Cambridge     FA  Faculty - Business
# 280          0     Alan Sheely    Cambridge     FA  Faculty - Business
# 281          0    Allison Gall    Cambridge     FA  Faculty - Business
# 282          0      Myles Tena    Cambridge     FA  Faculty - Business
# 283          0  Dessie Burruss    Cambridge     FA  Faculty - Business
#
#     Join\nDate  LWD       Type   Divison     Reports To  \
# 0    29-Aug-10  NaN  Full Time  Business    Abbas Houda
# ...

# %%
# Looking at some of the properties of this data set by looking at the data types for each columns.
df.dtypes
# Out:
# ID                                                                                                                               object
# Name                                                                                                                             object
# Location                                                                                                                         object
# Grade                                                                                                                            object
# Title                                                                                                                            object
# Join\nDate                                                                                                                       object
# LWD                                                                                                                              object
# ...

# %%
# Since the Data types shows all objects I run the describe method with 'O' to return all of objects.
# the describe method takes an include function that tells it whether to include all columns, Just numeric columns or just category columns.
df.describe(include = 'O')
# Out:
#          ID           Name Location Grade               Title Join\nDate  \
# count   282            284      270   284                 284        283
# unique  243            282       16     2                  12        143
# top       0  Zikida Koudou  Bristol    FA  Faculty - Business  14-Aug-16
# freq     40              2       49   282                 252         41
#
#               LWD       Type   Divison  Reports To  \
# count          11        284       284         280
# unique          2          1         1          15
# top     17-Dec-15  Full Time  Business  Ian Varley
# freq            6        284       284          33
#
#        Highest\nQualification\nLevel           Highest Qualification  \
# count                            278                             278
# unique                            18                              59
# top                          Masters  Master of Business Administrat
# ...

# %%
# count is the count of all non null values 
# unique is the number of unique values
# top is the most frequntly occuring value
# freq the number of times the most frequenlty occuring values occurs

# %%
# get the number of missing data points per column
missing_values_count = df.isnull().sum()

# look at the # of missing points in all of the 19 columns
missing_values_count[0:19]
# Out:
# ID                                                                                                                                 2
# Name                                                                                                                               0
# Location                                                                                                                          14
# Grade                                                                                                                              0
# Title                                                                                                                              0
# Join\nDate                                                                                                                         1
# LWD                                                                                                                              273
# ...

# %%
# Attempting to clean the data by dropping LWD column as you can see there are 273 missing values.
data = df.drop(['LWD'], axis = 1)

# %%
# Confirming the LWD column has been dropped
data.head(284)
# Out:
#             ID              Name   Location  Grade               Title  \
# 0    LT9210743        Jim Hunter     London     FA  Faculty - Business
# 1    LT9001784        Jose Nadal     London     FA  Faculty - Business
# 2    LT9062955     Pierre Cornet     London     FA  Faculty - Business
# 3            0       Sally Smith     London     FA  Faculty - Business
# 4            0      Ned Shearer      London  Chair  Faculty - Business
# ..         ...               ...        ...    ...                 ...
# 279          0    Cami Wiegand    Cambridge     FA  Faculty - Business
# 280          0     Alan Sheely    Cambridge     FA  Faculty - Business
# 281          0    Allison Gall    Cambridge     FA  Faculty - Business
# 282          0      Myles Tena    Cambridge     FA  Faculty - Business
# 283          0  Dessie Burruss    Cambridge     FA  Faculty - Business
#
#     Join\nDate       Type   Divison     Reports To  \
# 0    29-Aug-10  Full Time  Business    Abbas Houda
# ...

# %%
df.describe(include = 'O')
# Out:
#          ID           Name Location Grade               Title Join\nDate  \
# count   282            284      270   284                 284        283
# unique  243            282       16     2                  12        143
# top       0  Zikida Koudou  Bristol    FA  Faculty - Business  14-Aug-16
# freq     40              2       49   282                 252         41
#
#               LWD       Type   Divison  Reports To  \
# count          11        284       284         280
# unique          2          1         1          15
# top     17-Dec-15  Full Time  Business  Ian Varley
# freq            6        284       284          33
#
#        Highest\nQualification\nLevel           Highest Qualification  \
# count                            278                             278
# unique                            18                              59
# top                          Masters  Master of Business Administrat
# ...

# %%
data.head(284)
# Out:
#             ID              Name   Location  Grade               Title  \
# 0    LT9210743        Jim Hunter     London     FA  Faculty - Business
# 1    LT9001784        Jose Nadal     London     FA  Faculty - Business
# 2    LT9062955     Pierre Cornet     London     FA  Faculty - Business
# 3            0       Sally Smith     London     FA  Faculty - Business
# 4            0      Ned Shearer      London  Chair  Faculty - Business
# ..         ...               ...        ...    ...                 ...
# 279          0    Cami Wiegand    Cambridge     FA  Faculty - Business
# 280          0     Alan Sheely    Cambridge     FA  Faculty - Business
# 281          0    Allison Gall    Cambridge     FA  Faculty - Business
# 282          0      Myles Tena    Cambridge     FA  Faculty - Business
# 283          0  Dessie Burruss    Cambridge     FA  Faculty - Business
#
#     Join\nDate       Type   Divison     Reports To  \
# 0    29-Aug-10  Full Time  Business    Abbas Houda
# ...

# %%
# Save the cleaned dataset
df.to_csv('cleaned_dataset.csv', index=False)
